# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("results.k16.ssv", delim_whitespace=True, header=None, names = ["kind", "n", "error"])

# %%
data.sort_values(by='n').plot(figsize=(15, 10), x='n', y='error')
plt.show()

# %%
results = pd.read_csv("results/output.k4.10.dat", delim_whitespace=True, names = ['i', 'u'])

# %%
results.plot(figsize=(15, 10), x = 'i', y='u')
plt.show()
